# %% [markdown]
# ## Desafio 1
#
#
# Em uma imagem de baralho completo, localize um 7 de Copas e o destaque com um retângulo, indicando com um texto acima a identificação da carta (“7 de Copas”).
# As imagens se encontram no repositório do GitHub.
#
# Imagem da carta de 7 de Copas
#
# <img src="imagens/playing-cards-7-copas.jpg">
#
# Imagem do baralho completo
#
# <img src="imagens/playing-cards.jpg">

# %%
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
print(cv2.__version__)

#Pop-up do Matplotlib
#%matplotlib qt

#Exibição na mesma tela do Jupyter
# %matplotlib inline

plt.style.use('seaborn')
sns.set_style("whitegrid", {'axes.grid' : False})
# Out:
# 3.4.2
# /Users/michel.fernandes/anaconda/lib/python3.6/site-packages/joblib/_multiprocessing_helpers.py:28: UserWarning: [Errno 28] No space left on device.  joblib will operate in serial mode
#   warnings.warn('%s.  joblib will operate in serial mode' % (e,))

# %%
imagem = cv2.imread("imagens/playing-cards.jpg")
imagem = cv2.cvtColor(imagem, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(20,10))
plt.imshow(imagem)
plt.title("Original")
# Out:
# Text(0.5,1,'Original')

# %%
imagem_card = cv2.imread("imagens/playing-cards-7-copas.jpg")
imagem_card = cv2.cvtColor(imagem_card, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(5,5))
plt.imshow(imagem_card)
plt.title("Original")
# Out:
# Text(0.5,1,'Original')

# %%
# IMPLEMENTAR SOLUCAO
